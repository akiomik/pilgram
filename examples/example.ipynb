# %% [markdown]
# # pilgram example

# %% [markdown]
# ## setup

# %%
# !pip install pillow pilgram
# !wget "https://github.com/akiomik/pilgram/blob/master/examples/mtjimba.jpg?raw=true" -O mtjimba.jpg

# %% [markdown]
# ## original image

# %%
from IPython import display 

display.display_jpeg(display.Image('mtjimba.jpg'))

# %% [markdown]
# ## image with filter

# %%
from PIL import Image
import pilgram

im = Image.open('mtjimba.jpg')
pilgram._1977(im).save('mtjimba-1977.jpg')

display.display_jpeg(display.Image('mtjimba-1977.jpg'))
